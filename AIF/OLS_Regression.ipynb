# %% [markdown]
# <a href="https://colab.research.google.com/github/bkgsur/FinanceModelingComputationWithPython/blob/main/AIF/OLS_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from pylab import plt

# %%
def f(x):
  return 2*(x**2) - (x**3)/3

x = np.linspace(-2,4,25)
y = f(x)

# %% [markdown]
# Linear Regression:
#
# ![image.png](data:image/png;base64,...)

# %%
#Assuming linear relationship
beta = np.cov(x,y,ddof=0)[1,0]/np.var(x)
beta
alpha = y.mean() - beta*x.mean()

y_ = alpha + beta*x
mse = ((y-y_)**2).mean()
mse
# Out:
# 10.721953125

# %%
plt.figure(figsize =(10,6))
plt.plot(x,y,'ro', label= 'Original Data')
plt.plot(x,y_, lw=3.0, label="linear regression" )
plt.legend()

# %%
# Higher order polynomials

plt.figure(figsize=(10,6))
plt.plot(x,y,'ro', label = 'sample data')
for deg in [1,2,3,4]:
  reg = np.polyfit(x,y,deg=deg)
  y_ = np.polyval(reg,x)
  mse = ((y-y_)**2).mean()
  print(f'deg = {deg}| MSE = {mse:.9f}')
  plt.plot(x,y_, label= f'deg ={deg}')
plt.legend()
# Out:
# deg = 1| MSE = 10.721953125
# deg = 2| MSE = 2.312578125
# deg = 3| MSE = 0.000000000
# deg = 4| MSE = 0.000000000
